# %%
import cv2

# %%
def load_image(filename):
    return cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
from random import choice

rnd = choice(os.listdir('../dataset/grayscale/train/homer_simpson/'))
print(rnd)
filename = f"../dataset/grayscale/train/homer_simpson/{rnd}"
print(filename)
# Out:
# pic_2254.jpg
# ../dataset/grayscale/train/homer_simpson/pic_2254.jpg

# %%
imshow(load_image(filename), cmap='gray')

# %%
b = '../dataset/grayscale/train'

# %%
num_classes = 10
grid_size = 10
by_factor = grid_size // num_classes
fs = list()
for i in range(grid_size*by_factor):
    for c in os.listdir(b):
        fs.append(f"{b}/{c}/{os.listdir(f'{b}/{c}')[i]}")

# %%
fs[:5]
# Out:
# ['../dataset/grayscale/train/krusty_the_clown/pic_0026.jpg',
#  '../dataset/grayscale/train/ned_flanders/pic_0026.jpg',
#  '../dataset/grayscale/train/homer_simpson/pic_2184.jpg',
#  '../dataset/grayscale/train/lisa_simpson/pic_0026.jpg',
#  '../dataset/grayscale/train/marge_simpson/pic_0026.jpg']

# %%
res = list()
curr_fs = list()
for f in fs:
    curr_fs.append(f)
    if len(curr_fs) == grid_size:
        imgs = [load_image(f_) for f_ in curr_fs]
        res.append(np.array(imgs))
        curr_fs = list()

# %%
res = np.array(res)
res.shape
# Out:
# (10, 10, 28, 28)

# %%
figsize(15, 15)
imshow(np.concatenate(res.reshape((grid_size, grid_size*28, 28)), axis=1), cmap='gray')
plt.axis('off');
plt.savefig('images/grayscale-overview.jpg', bbox_inches='tight')
